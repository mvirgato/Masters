# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('d2ACS.dat', sep="\t", header = None)
data
# Out:
#                   0              1              2              3  \
# 0          0.000001   4.146830e-61   1.311343e-59   4.146830e-58
# 1          0.000001   1.852321e-61   5.857553e-60   1.852321e-58
# 2          0.000002   8.274013e-62   2.616473e-60   8.274013e-59
# 3          0.000002   3.695866e-62   1.168735e-60   3.695866e-59
# 4          0.000003   1.650883e-62   5.220549e-61   1.650883e-59
# 5          0.000003   7.374222e-63   2.331934e-61   7.374222e-60
# 6          0.000004   3.293944e-63   1.041637e-61   3.293944e-60
# 7          0.000005   1.471351e-63   4.652820e-62   1.471351e-60
# 8          0.000006   6.572282e-64   2.078338e-62   6.572282e-61
# 9          0.000008   2.935731e-64   9.283596e-63   2.935731e-61
# 10         0.000010   1.311343e-64   4.146830e-63   1.311343e-61
# 11         0.000013   5.857553e-65   1.852321e-63   5.857553e-62
# 12         0.000016   2.616473e-65   8.274013e-64   2.616473e-62
# ...

# %%
# !ls
# Out:
# brian_fun_times.tar.gz	d2ACS.dat  d5ACS.dat  d8ACS.dat   Untitled.ipynb
# d10ACS.dat		d3ACS.dat  d6ACS.dat  d9ACS.dat
# d1ACS.dat		d4ACS.dat  d7ACS.dat  plotter.py
